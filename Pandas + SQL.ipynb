# %%
pip install pandasql
# Out:
# Collecting pandasql
#   Downloading pandasql-0.7.3.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.11/site-packages (from pandasql) (1.26.4)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.11/site-packages (from pandasql) (2.1.4)
# Requirement already satisfied: sqlalchemy in /opt/anaconda3/lib/python3.11/site-packages (from pandasql) (2.0.25)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->pandasql) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->pandasql) (2023.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from sqlalchemy->pandasql) (4.9.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->pandasql) (1.16.0)
# Building wheels for collected packages: pandasql
#   Building wheel for pandasql (setup.py) ... done
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26771 sha256=0138a302224f26f1c863c25acdf5bfb80d98591ea5d169798ebb56371c5ab728
#   Stored in directory: /Users/frederik.lindsey/Library/Caches/pip/wheels/68/5d/a5/edc271b998f909801d7956959f699b976cc9896075dc47c153
# Successfully built pandasql
# Installing collected packages: pandasql
# Successfully installed pandasql-0.7.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from pandasql import sqldf
from pandasql import load_births

births = load_births()

type(births)
# Out:
# pandas.core.frame.DataFrame

# %%
print(births.dtypes)
# Out:
# date      datetime64[ns]
# births             int64
# dtype: object

# %%
print(sqldf("SELECT * FROM births limit 5;"))
# Out:
#                          date  births
# 0  1975-01-01 00:00:00.000000  265775
# 1  1975-02-01 00:00:00.000000  241045
# 2  1975-03-01 00:00:00.000000  268849
# 3  1975-04-01 00:00:00.000000  247455
# 4  1975-05-01 00:00:00.000000  254545

# %%
print(births.head())
# Out:
#         date  births
# 0 1975-01-01  265775
# 1 1975-02-01  241045
# 2 1975-03-01  268849
# 3 1975-04-01  247455
# 4 1975-05-01  254545

# %%
q = """
      SELECT strftime('%Y', date) AS DOB, sum(births) as "Total Births"
      FROM births
      GROUP BY 1
      LIMIT 10;  
"""

print(sqldf(q))
# Out:
#     DOB  Total Births
# 0  1975       3136965
# 1  1976       6304156
# 2  1979       3333279
# 3  1982       3612258
# 4  1983       7333238
# 5  1986       7308074
# 6  1987       3760561
# 7  1988       3756547
# 8  1990       7718904
# 9  1991      11714356

# %%
df1 = sqldf(q)
type(df1)
# Out:
# pandas.core.frame.DataFrame
