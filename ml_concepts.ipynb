# %% [markdown]
# #### 1.Variable Reduction/Importance
# - 1. Reduce with Regualrized Regression: LASSO/LARS, or combine via Elastic NET
#     - can also reduce with PCA. This examines variables via Variance per variable
# - 2. Random Forest will give you the option to visualize variable importance. Cool, easy, accessible.
